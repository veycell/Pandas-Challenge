# %%
import os
import csv
import pandas as pd
import requests
import yfinance as yf
import numpy as np
import datetime as dt
import matplotlib as plt

# %%
file=os.path.join("..","Homework-07-Group Project","Stock Betas.csv")

# %%
stocks=pd.read_csv('Stock Betas.csv')
stocks
stocks.sample(5)
# Out:
#     Tickers                     Title                Industry  \
# 461     UNH  United Health Group Inc.             Health Care
# 160     DXC            DXC Technology  Information Technology
# 174     EQR        Equity Residential             Real Estate
# 326    MNST          Monster Beverage        Consumer Staples
# 317     MTD            Mettler Toledo             Health Care
#
#               Headquarters Location         Date first added  Beta long term  \
# 461             Managed Health Care    Minnetonka, Minnesota            0.96
# 160  IT Consulting & Other Services  Tysons Corner, Virginia             NaN
# 174               Residential REITs        Chicago, Illinois             NaN
# 326                     Soft Drinks       Corona, California             NaN
# 317  Life Sciences Tools & Services           Columbus, Ohio             NaN
#
#      Beta current time
# 461               0.96
# 160                NaN
# 174                NaN
# 326                NaN
# 317                NaN

# %%
tickers = stocks["Tickers"]
list_tickers=tickers.tolist()
start_date="2020-01-31"
end_date=pd.datetime.now().date()
yesterday = end_date - dt.timedelta(days=3)

# %%
closing_price_stocks=yf.download(list_stocks,start_date,yesterday)
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 2 Failed downloads:
# - BF.B: No data found for this date range, symbol may be delisted
# - BRK.B: No data found, symbol may be delisted

# %%
aa = closing_price_stockss.index
aa.get_level_values(1)
# Out:
# Index(['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'ABT', 'ACN', 'ADBE',
#        ...
#        'XLNX', 'XOM', 'XRAY', 'XRX', 'XYL', 'YUM', 'ZBH', 'ZBRA', 'ZION',
#        'ZTS'],
#       dtype='object', length=3030)

# %%
closing_price_stockss=closing_price_stocks.T

# %%
AA = closing_price_stockss.iloc[closing_price_stockss.index.get_level_values(0) == 'Adj Close']
AA.reset_index(inplace=True)  
AA = AA.drop(columns=['level_0'])
AA = AA.set_index('level_1')
AA.index.names = ['Tickers']

# %%
AAA = pd.merge(AA, stocks[['Tickers','Industry']],left_index=True, right_on="Tickers").set_index('Tickers')
AAA.sample(5)
# Out:
#          2020-01-31 00:00:00  2020-02-03 00:00:00  2020-02-04 00:00:00  \
# Tickers
# PH                194.871674           197.301483           205.258057
# HII               259.776703           260.125061           263.817688
# AKAM               93.349998            93.680000            95.220001
# DRE                36.084621            36.084621            36.452324
# LYB                76.706924            77.652710            80.509758
#
#          2020-02-05 00:00:00  2020-02-06 00:00:00  2020-02-07 00:00:00  \
# Tickers
# PH                209.559998           209.850006           207.820007
# HII               268.296570           266.923035           267.878571
# AKAM               95.949997            96.949997            96.120003
# DRE                36.462261            36.521889            36.402634
# LYB                82.834808            82.145172            80.884132
#
#          2020-02-10 00:00:00  2020-02-11 00:00:00  2020-02-12 00:00:00  \
# Tickers
# PH                209.449997           212.250000           213.910004
# HII               267.659607           266.813568           268.814148
# AKAM               95.760002            96.370003            97.449997
# DRE                37.058537            37.386486            37.625000
# LYB                80.716652            82.726440            84.342148
#
#          2020-02-13 00:00:00  ...  2020-03-30 00:00:00  2020-03-31 00:00:00  \
# Tickers                       ...
# PH                213.029999  ...           130.350006           129.729996
# HII               249.186569  ...           189.539993           182.210007
# AKAM               99.599998  ...            94.190002            91.489998
# DRE                37.939999  ...            33.049999            32.380001
# LYB                82.253540  ...            49.580002            49.630001
#
#          2020-04-01 00:00:00  2020-04-02 00:00:00  2020-04-03 00:00:00  \
# Tickers
# PH                116.089996           118.839996           115.809998
# HII               173.139999           180.639999           181.039993
# AKAM               91.599998            93.120003            95.360001
# DRE                30.180000            30.030001            29.590000
# LYB                45.029999            45.919998            46.099998
#
#          2020-04-06 00:00:00  2020-04-07 00:00:00  2020-04-08 00:00:00  \
# Tickers
# PH                130.770004           132.360001           141.389999
# HII               193.710007           191.740005           195.440002
# AKAM               97.790001            95.230003            97.370003
# DRE                32.200001            31.520000            33.419998
# LYB                49.880001            51.650002            55.470001
#
#          2020-04-09 00:00:00                Industry
# Tickers
# PH                145.169998             Industrials
# HII               192.389999             Industrials
# AKAM               95.389999  Information Technology
# DRE                35.560001             Real Estate
# LYB                58.930000               Materials
#
# [5 rows x 50 columns]

# %%
AAA['MeanTickers'] = AAA.mean(axis=1)
AAA.sample()
# Out:
#          2020-01-31 00:00:00  2020-02-03 00:00:00  2020-02-04 00:00:00  \
# Tickers
# EL                194.665115           195.702469           199.911774
#
#          2020-02-05 00:00:00  2020-02-06 00:00:00  2020-02-07 00:00:00  \
# Tickers
# EL                200.809494           210.993591           208.430115
#
#          2020-02-10 00:00:00  2020-02-11 00:00:00  2020-02-12 00:00:00  \
# Tickers
# EL                208.150818           209.287949           214.245331
#
#          2020-02-13 00:00:00  ...  2020-03-31 00:00:00  2020-04-01 00:00:00  \
# Tickers                       ...
# EL                214.345078  ...           159.339996           153.380005
#
#          2020-04-02 00:00:00  2020-04-03 00:00:00  2020-04-06 00:00:00  \
# Tickers
# EL                149.210007           154.080002                160.5
#
#          2020-04-07 00:00:00  2020-04-08 00:00:00  2020-04-09 00:00:00  \
# Tickers
# EL                163.169998           165.729996           164.830002
#
#                  Industry  MeanTickers
# Tickers
# EL       Consumer Staples   181.378445
#
# [1 rows x 51 columns]

# %%
AAA.drop(columns=['MeanIndustry'],inplace=True)

# %%
grouped_industry=AAA.groupby(["Industry"]).agg([np.mean])

# %%
grouped_industry
# Out:
#                        2020-01-31 00:00:00 2020-02-03 00:00:00  \
#                                       mean                mean
# Industry
# Communication Services          192.960025          197.952561
# Consumer Discretionary          232.571576          232.935082
# Consumer Staples                 92.511399           92.491765
# Energy                           48.576924           47.903879
# Financials                      110.835056          111.856710
# Health Care                     171.584207          172.717028
# Industrials                     135.730743          136.242720
# Information Technology          136.380031          138.267749
# Materials                       106.386830          108.827627
# Real Estate                     123.326239          123.851574
# Utilities                        85.918103           86.248392
#
#                        2020-02-04 00:00:00 2020-02-05 00:00:00  \
#                                       mean                mean
# Industry
# Communication Services          196.477271          196.180982
# Consumer Discretionary          235.128526          238.226369
# Consumer Staples                 93.101366           94.007353
# Energy                           48.351176           50.315500
# Financials                      113.040821          114.476276
# Health Care                     175.960170          179.937287
# Industrials                     138.516649          140.222213
# Information Technology          141.501607          141.848285
# Materials                       110.867326          112.558130
# Real Estate                     125.172562          124.959887
# Utilities                        85.333223           85.743418
#
#                        2020-02-06 00:00:00 2020-02-07 00:00:00  \
#                                       mean                mean
# Industry
# Communication Services          199.067544          198.652969
# Consumer Discretionary          238.583406          237.671120
# Consumer Staples                 94.263063           94.606857
# Energy                           49.712873           49.248160
# Financials                      114.377377          114.037669
# Health Care                     180.262045          178.376769
# Industrials                     140.303554          139.481039
# Information Technology          142.176267          140.253320
# Materials                       112.444668          110.917337
# Real Estate                     125.548521          125.665340
# Utilities                        85.795901           85.600374
#
#                        2020-02-10 00:00:00 2020-02-11 00:00:00  \
#                                       mean                mean
# Industry
# Communication Services          201.302163          201.757122
# Consumer Discretionary          239.298173          240.928244
# Consumer Staples                 95.031513           94.818816
# Energy                           48.910853           49.441597
# Financials                      114.495013          115.252787
# Health Care                     179.206339          180.944598
# Industrials                     140.265178          140.892332
# Information Technology          141.764616          142.364429
# Materials                       110.901830          110.989433
# Real Estate                     127.054003          128.208534
# Utilities                        85.947862           86.190803
#
#                        2020-02-12 00:00:00 2020-02-13 00:00:00  ...  \
#                                       mean                mean  ...
# Industry                                                        ...
# Communication Services          203.533643          203.201322  ...
# Consumer Discretionary          243.246518          243.662508  ...
# Consumer Staples                 94.981597           95.457617  ...
# Energy                           50.193799           50.090003  ...
# Financials                      115.293755          115.608930  ...
# Health Care                     181.721602          181.713871  ...
# Industrials                     142.123564          141.407345  ...
# Information Technology          143.910894          144.098226  ...
# Materials                       111.641017          111.213316  ...
# Real Estate                     129.219962          130.123251  ...
# Utilities                        86.159317           87.061330  ...
#
#                        2020-03-30 00:00:00 2020-03-31 00:00:00  \
#                                       mean                mean
# Industry
# Communication Services          159.519331          160.152145
# Consumer Discretionary          174.019543          170.474855
# Consumer Staples                 82.230574           80.734038
# Energy                           23.904421           24.392631
# Financials                       84.543216           81.783208
# Health Care                     153.476181          152.873004
# Industrials                      98.801592           97.183243
# Information Technology          113.279653          110.673408
# Materials                        84.872142           83.467500
# Real Estate                     103.961307          100.840034
# Utilities                        72.599286           69.515000
#
#                        2020-04-01 00:00:00 2020-04-02 00:00:00  \
#                                       mean                mean
# Industry
# Communication Services          153.296587          155.509916
# Consumer Discretionary          161.529099          161.200684
# Consumer Staples                 79.270316           80.735950
# Energy                           23.006398           25.139996
# Financials                       77.218444           79.177539
# Health Care                     146.225590          149.473297
# Industrials                      91.537551           93.227613
# Information Technology          104.825801          106.457302
# Materials                        79.501429           80.215715
# Real Estate                      95.253558           96.305279
# Utilities                        65.270357           67.321071
#
#                        2020-04-03 00:00:00 2020-04-06 00:00:00  \
#                                       mean                mean
# Industry
# Communication Services          152.615435          163.418664
# Consumer Discretionary          158.867175          175.758847
# Consumer Staples                 81.414939           84.395988
# Energy                           25.042806           26.479254
# Financials                       78.141086           84.667100
# Health Care                     146.923373          157.220571
# Industrials                      91.698318           98.098917
# Information Technology          104.711076          114.566657
# Materials                        77.741429           83.533571
# Real Estate                      95.527996          102.118399
# Utilities                        64.904643           70.113214
#
#                        2020-04-07 00:00:00 2020-04-08 00:00:00  \
#                                       mean                mean
# Industry
# Communication Services          163.235100          166.179846
# Consumer Discretionary          178.658253          185.708412
# Consumer Staples                 84.151542           85.191469
# Energy                           26.977148           29.016216
# Financials                       84.712018           88.053534
# Health Care                     156.465536          162.815029
# Industrials                      98.397114          102.035764
# Information Technology          113.870931          117.883783
# Materials                        85.691071           90.369286
# Real Estate                     101.700984          108.823452
# Utilities                        69.186428           72.993929
#
#                        2020-04-09 00:00:00 MeanTickers
#                                       mean        mean
# Industry
# Communication Services          166.733649  176.190987
# Consumer Discretionary          188.679366  203.841803
# Consumer Staples                 86.100002   87.051403
# Energy                           28.686370   35.874517
# Financials                       92.308480   96.077529
# Health Care                     163.665254  162.634645
# Industrials                     103.571805  112.878220
# Information Technology          118.227477  123.509514
# Materials                        93.646786   95.166276
# Real Estate                     114.017826  113.997461
# Utilities                        76.481428   77.153118
#
# [11 rows x 50 columns]

# %%
x_label=
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-419-c4109b193733> in <module>
# ----> 1 x_label=df.grouped_industry("Industry")
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'grouped_industry'
